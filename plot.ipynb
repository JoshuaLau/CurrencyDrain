# %% [raw]
# Country Infant Mortality Analysis

# %% [raw]
# This project aims to find the best countries to have a baby in, given various measures.

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as mlp

# %%
main_csv = pd.read_csv("2016-alcohol-prevale-alcohol-disorders-QueryResult.csv")
main_csv
# Out:
#                          name  infantmortality  \
# 0                     Albania             14.0
# 1                     Algeria             27.7
# 2                     Andorra              3.6
# 3                      Angola             76.5
# 4                   Argentina             11.1
# 5                     Armenia             13.1
# 6                   Australia              3.2
# 7                     Austria              3.4
# 8                  Azerbaijan             24.7
# 9                     Bahamas             11.7
# 10                    Bahrain              9.2
# 11                 Bangladesh             32.9
# 12                   Barbados              8.8
# 13                    Belarus              3.6
# 14                    Belgium              3.4
# 15                     Belize             19.3
# 16                      Benin             65.9
# 17                    Bermuda              2.5
# 18                     Bhutan             33.9
# ...

# %%
data = pd.DataFrame(main_csv)
data
# Out:
#                          name  infantmortality  \
# 0                     Albania             14.0
# 1                     Algeria             27.7
# 2                     Andorra              3.6
# 3                      Angola             76.5
# 4                   Argentina             11.1
# 5                     Armenia             13.1
# 6                   Australia              3.2
# 7                     Austria              3.4
# 8                  Azerbaijan             24.7
# 9                     Bahamas             11.7
# 10                    Bahrain              9.2
# 11                 Bangladesh             32.9
# 12                   Barbados              8.8
# 13                    Belarus              3.6
# 14                    Belgium              3.4
# 15                     Belize             19.3
# 16                      Benin             65.9
# 17                    Bermuda              2.5
# 18                     Bhutan             33.9
# ...

# %%
countries = data.iloc[:, 0]
countries
# Out:
# 0                       Albania
# 1                       Algeria
# 2                       Andorra
# 3                        Angola
# 4                     Argentina
# 5                       Armenia
# 6                     Australia
# 7                       Austria
# 8                    Azerbaijan
# 9                       Bahamas
# 10                      Bahrain
# 11                   Bangladesh
# 12                     Barbados
# 13                      Belarus
# 14                      Belgium
# 15                       Belize
# 16                        Benin
# 17                      Bermuda
# 18                       Bhutan
# 19                      Bolivia
# 20                     Botswana
# 21                       Brazil
# 22                     Bulgaria
# 23                 Burkina Faso
# 24                      Burundi
# 25                     Cambodia
# 26                     Cameroon
# 27                       Canada
# 28     Central African Republic
# ...

# %%
infant_mortality = data.iloc[:, 1]
substance_use_disorders = data.iloc[:, 2]
agriculture = data.iloc[:, 3]
gdp = data.iloc[:, 4]
literacy = data.iloc[:, 5]
net_migration = data.iloc[:, 6]
population
