# %% [raw]
# Country Infant Mortality Analysis

# %% [raw]
# This project aims to find the best countries to have a baby in, given various measures.

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as mlp

# %%
main_csv = pd.read_csv("UpdatedTable.csv")
main_csv
# Out:
#                          name  infantMortality                     govt  \
# 0                     Albania             14.0                 Republic
# 1                     Algeria             27.7                 Republic
# 2                     Andorra              3.6  Constitutional monarchy
# 3                      Angola             76.5                 Republic
# 4                   Argentina             11.1                 Republic
# 5                     Armenia             13.1                 Republic
# 6                   Australia              3.2  Constitutional monarchy
# 7                     Austria              3.4                 Republic
# 8                  Azerbaijan             24.7                 Republic
# 9                     Bahrain              9.2  Constitutional monarchy
# 10                 Bangladesh             32.9                 Republic
# 11                   Barbados              8.8  Constitutional monarchy
# ...

# %%
data = pd.DataFrame(main_csv)
data
# Out:
#                          name  infantMortality                     govt  \
# 0                     Albania             14.0                 Republic
# 1                     Algeria             27.7                 Republic
# 2                     Andorra              3.6  Constitutional monarchy
# 3                      Angola             76.5                 Republic
# 4                   Argentina             11.1                 Republic
# 5                     Armenia             13.1                 Republic
# 6                   Australia              3.2  Constitutional monarchy
# 7                     Austria              3.4                 Republic
# 8                  Azerbaijan             24.7                 Republic
# 9                     Bahrain              9.2  Constitutional monarchy
# 10                 Bangladesh             32.9                 Republic
# 11                   Barbados              8.8  Constitutional monarchy
# ...

# %%
mlp.scatter(data.substanceAbuse, data.infantMortality)
mlp.show()

# %%
mlp.scatter(data.GDPPC, data.infantMortality)
mlp.show()

# %%
mlp.scatter(data.literacy, data.infantMortality)
mlp.show()

# %%
mlp.scatter(data.netMigration, data.infantMortality)
mlp.show()

# %%
mlp.scatter(data.substanceAbuse, data.population)
mlp.show()
