# %% [raw]
# Country Infant Mortality Analysis

# %% [raw]
# This project aims to find the best countries to have a baby in, given various measures.

# %%
import numpy as np
import pandas as pd

# %%
fileName = "UpdatedTable.csv"
data = pd.read_csv(fileName)

# %%
newColData = data.rename(columns=
                         {"prevalence_alcohol_and_substance_use_disorders_both_age_standardized_percent" : "substanceAbuse",
                          "infantmortality" : "infantMortality",
                          "gdppc" : "GDPPC",
                          "netmigration" : "netMigration"})
newColData
# Out:
#                          name  infantMortality                     govt  \
# 0                     Albania             14.0                 Republic
# 1                     Algeria             27.7                 Republic
# 2                     Andorra              3.6  Constitutional monarchy
# 3                      Angola             76.5                 Republic
# 4                   Argentina             11.1                 Republic
# 5                     Armenia             13.1                 Republic
# 6                   Australia              3.2  Constitutional monarchy
# 7                     Austria              3.4                 Republic
# 8                  Azerbaijan             24.7                 Republic
# 9                     Bahrain              9.2  Constitutional monarchy
# 10                 Bangladesh             32.9                 Republic
# 11                   Barbados              8.8  Constitutional monarchy
# ...

# %%
print(newColData.to_string())
# Out:
#                          name  infantMortality                     govt  substanceAbuse   GDPPC  literacy  netMigration  population
# 0                     Albania             14.0                 Republic        2.325538    3965     0.987          -3.3     3038594
# 1                     Algeria             27.7                 Republic        1.485915    4206     0.800          -0.9    39670000
# 2                     Andorra              3.6  Constitutional monarchy        2.141102   42500     1.000           0.0       86165
# 3                      Angola             76.5                 Republic        1.923945    4102     0.711          -0.1    25020000
# 4                   Argentina             11.1                 Republic        3.118683   13432     0.981          -0.1    43420000
# 5                     Armenia             13.1                 Republic        2.365449    3499     0.998          -5.7     3018000
# ...

# %%
newColData = newColData.fillna("Republic")
# Out:
#                          name  infantMortality                     govt  substanceAbuse   GDPPC  literacy  netMigration  population
# 0                     Albania             14.0                 Republic        2.325538    3965     0.987          -3.3     3038594
# 1                     Algeria             27.7                 Republic        1.485915    4206     0.800          -0.9    39670000
# 2                     Andorra              3.6  Constitutional monarchy        2.141102   42500     1.000           0.0       86165
# 3                      Angola             76.5                 Republic        1.923945    4102     0.711          -0.1    25020000
# 4                   Argentina             11.1                 Republic        3.118683   13432     0.981          -0.1    43420000
# 5                     Armenia             13.1                 Republic        2.365449    3499     0.998          -5.7     3018000
# ...
